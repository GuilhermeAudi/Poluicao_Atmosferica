# %%
import numpy as np #importa numpy

# Criando um vetor de dados aleatórios
data = np.random.rand(1000,2)

# Verificando o tamanho do vetor
print(data.shape)
print(np.size(data))

# Print de uma amostra dos dados
print(data[0:10])
print(data[0:10].shape)
# Out:
# (1000, 2)
# 2000
# [[0.69263438 0.20121787]
#  [0.11729148 0.30081069]
#  [0.37344382 0.94854305]
#  [0.76259081 0.86039957]
#  [0.8727711  0.69814034]
#  [0.00411498 0.56421208]
#  [0.95293702 0.34924969]
#  [0.26103131 0.2713223 ]
#  [0.76312098 0.23360294]
#  [0.00120284 0.16750139]]
# (10, 2)

# %%
# Usando Monte-Carlo
dataMax = 1000
#limite max
dataMin = 10
#limite min
data = (dataMax - dataMin)*data + dataMin
print(data[0:10])
# Out:
# [[695.70803623 209.20569379]
#  [126.11856497 307.80258696]
#  [379.7093844  949.05762004]
#  [764.96490312 861.79557159]
#  [874.04339299 701.1589372 ]
#  [ 14.07383326 568.56995982]
#  [953.40764642 355.75719512]
#  [268.42099959 278.60907652]
#  [765.48977239 241.26690668]
#  [ 11.19081561 175.82637934]]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3) # cria gráficos na ordem entre parenteses
ax[0].plot(data)
ax[1].plot(data[:,0]) #recorte do intervalo
ax[2].plot(data[:,1])
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
# Criando um dado 2D 
data3d = np.sin(np.random.rand(1000,1000))
print(data3d)
# Out:
# [[0.68517781 0.75931782 0.8294784  ... 0.04328623 0.17718275 0.31370084]
#  [0.62247163 0.08267372 0.72086246 ... 0.35680014 0.60324582 0.24913826]
#  [0.06386792 0.00168859 0.64964725 ... 0.29649097 0.68623553 0.65076514]
#  ...
#  [0.01478712 0.70545421 0.2371391  ... 0.53062454 0.83239977 0.60276026]
#  [0.15622599 0.69506753 0.83195079 ... 0.23244591 0.64112825 0.51463331]
#  [0.67381081 0.35629411 0.78954588 ... 0.41206672 0.25994842 0.82893819]]

# %%
# Plotando um dado 3D
fig2, ax2 = plt.subplots()
ax2.pcolor(data3d)

# %%
# Criando vertor temporal
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1, "h"))
print(dtime[1:10])
print(dtime.shape)
print(type(dtime))
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %% [markdown]
# # PANDAS

# %%
import pandas as pd

# Criando um dataframe
df = pd.DataFrame()

# %%
# Monstrando um dataframe
df['datetime'] = dtime

# %%
# Criando uma coluna random dentro do dataframe df
df['random'] = np.random.rand(df.shape[0])

# %%
df['random'][1:10]
# Out:
# 1    0.139918
# 2    0.740179
# 3    0.173837
# 4    0.537839
# 5    0.980469
# 6    0.797439
# 7    0.606071
# 8    0.595851
# 9    0.806381
# Name: random, dtype: float64

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime'])
df
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.478837
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.139918
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.740179
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.173837
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.537839
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.392025
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.665518
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.246293
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.797209
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.721403
#
# [8760 rows x 2 columns]

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day

# %%
tt = np.arange(0,df.shape[0],1)
print(tt.shape)
df['sazonal'] = (np.cos(tt/(360*4)))
df['timeSeries'] = 10*df['sazonal']+df['random']
#df['sazonal'].plot()
df['timeSeries'].plot(color='red')
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
df
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.478837  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.139918  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.740179  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.173837  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.537839  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.392025  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.665518  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.246293  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.797209  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.721403  2022     12   31  0.979958
#
#                      timeSeries
# datetime
# 2022-01-01 00:00:00   10.478837
# 2022-01-01 01:00:00   10.139915
# 2022-01-01 02:00:00   10.740169
# 2022-01-01 03:00:00   10.173815
# 2022-01-01 04:00:00   10.537801
# ...                         ...
# 2022-12-31 19:00:00   10.186032
# 2022-12-31 20:00:00   10.460926
# 2022-12-31 21:00:00   10.043095
# 2022-12-31 22:00:00   10.595402
# 2022-12-31 23:00:00   10.520982
#
# [8760 rows x 7 columns]

# %%
# Salvar meu dataframe

df.to_csv(r'C:\Users\guilh\OneDrive\Desktop\polatm\ENS410064\dados\brutos\datosat1.csv')

# %%
# Criando uma função
def noiseCreation(path, year):
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas

    Criado por Leonardo
    """
    
    # Criando um dataframe
    df = pd.DataFrame()
    
    # Criando vertor temporal
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h"))
    
    # Monstrando um dataframe
    df['datetime'] = dtime
        
    # Datetime como index do dataframe
    df = df.set_index(df['datetime'])
    
    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day
    
    # Crio uma coluna random
    df['random'] = np.random.rand(df.shape[0])
    
    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = (np.cos(tt/(360*4)))
    df['timeSeries'] = 10*df['sazonal']+df['random']
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red')
    df.to_csv(path+'/noise_'+str(year)+'.csv')
    
    return df

# %%
path = 'C:/Users/guilh/OneDrive/Desktop/polatm/ENS410064/dados/brutos'
df2 = noiseCreation(path,2050)
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010):
    print(ii)
    df = noiseCreation(path,ii)
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %%
df
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.918008  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.788947  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.841879  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.688904  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.240441  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.327938  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.684663  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.723576  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.961595  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.776079  0.979958
#
#                      timeSeries
# datetime
# 2009-01-01 00:00:00   10.918008
# 2009-01-01 01:00:00   10.788945
# 2009-01-01 02:00:00   10.841869
# 2009-01-01 03:00:00   10.688882
# 2009-01-01 04:00:00   10.240403
# ...                         ...
# 2009-12-31 19:00:00   10.121946
# 2009-12-31 20:00:00   10.480071
# 2009-12-31 21:00:00   10.520379
# 2009-12-31 22:00:00   10.759788
# 2009-12-31 23:00:00   10.575657
#
# [8760 rows x 7 columns]

# %%
anos = [2001,2030,2032,2053,2060]

for ano in anos:
    print(ano)
    if ano > 2030:
        df = noiseCreation(path,ano)
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %%
import os
files = os.listdir(path)
print(files)

allData = []
for file in files:
    if file.endswith('.csv'):
        print(file)
        data = pd.read_csv(path+'/'+file)
        allData.append(data)
# Out:
# ['datosat1.csv', 'noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv']
# datosat1.csv
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %%
allDataDf = pd.concat(allData)

# %%
allDataDf
# Out:
#                  datetime           datetime.1    random  year  month  day  \
# 0     2022-01-01 00:00:00  2022-01-01 00:00:00  0.478837  2022      1    1
# 1     2022-01-01 01:00:00  2022-01-01 01:00:00  0.139918  2022      1    1
# 2     2022-01-01 02:00:00  2022-01-01 02:00:00  0.740179  2022      1    1
# 3     2022-01-01 03:00:00  2022-01-01 03:00:00  0.173837  2022      1    1
# 4     2022-01-01 04:00:00  2022-01-01 04:00:00  0.537839  2022      1    1
# ...                   ...                  ...       ...   ...    ...  ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  0.786601  2060     12   31
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  0.505096  2060     12   31
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  0.646817  2060     12   31
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  0.451554  2060     12   31
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  0.563786  2060     12   31
#
#        sazonal  timeSeries
# 0     1.000000   10.478837
# 1     1.000000   10.139915
# 2     0.999999   10.740169
# 3     0.999998   10.173815
# 4     0.999996   10.537801
# ...        ...         ...
# 8779  0.982630   10.612901
# 8780  0.982759   10.332682
# 8781  0.982887   10.475685
# 8782  0.983014   10.281698
# 8783  0.983142   10.395203
#
# [113976 rows x 8 columns]

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries'])
